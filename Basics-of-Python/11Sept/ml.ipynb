# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Supervised
# 1. Regression
# 2. Classification
# ## Unsupervised
# 1. Clustering

# %% [markdown]
# ## Steps for implementing linear regression
#
# 1. importing req libraries (scikit learn)
# 2. Gathering prepared data
# 3. choosing right model
# 4. defing our target y and feature x
#    x = feature
#    y = target
# 5. splitting our data into a training and testing
#    x-train, y-train, x-test, y-test
# 6. we will train our model with x-train and y-train
# 7. testing/validating our data
# 8. model evaluation (accuracy, recall, etc.,)
# 9. visualization

# %%
pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    -------- ------------------------------- 1.8/8.7 MB 11.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.3/8.7 MB 17.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 17.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    --- ------------------------------------ 3.4/38.5 MB 16.9 MB/s eta 0:00:03
#    -------- ------------------------------- 8.1/38.5 MB 19.9 MB/s eta 0:00:02
#    ------------- -------------------------- 13.4/38.5 MB 23.2 MB/s eta 0:00:02
#    -------------------- ------------------- 20.2/38.5 MB 24.8 MB/s eta 0:00:01
#    --------------------------- ------------ 26.7/38.5 MB 26.2 MB/s eta 0:00:01
#    -------------------------------- ------- 31.2/38.5 MB 25.2 MB/s eta 0:00:01
#    ------------------------------------ --- 35.1/38.5 MB 24.6 MB/s eta 0:00:01
# ...

# %%
import sklearn
