# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df = df.drop(columns=['Engine Fuel Type', 'Market Category', 'Vehicle Size', 'Popularity', 'Number of Doors', 'Vehicle Style'])

# %%
df
# Out:
#           Make       Model  Year  Engine HP  Engine Cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       Transmission Type      Driven_Wheels  highway MPG  city mpg   MSRP
# 0                MANUAL   rear wheel drive           26        19  46135
# 1                MANUAL   rear wheel drive           28        19  40650
# ...

# %%
df.head()
# Out:
#   Make       Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011      335.0               6.0            MANUAL
# 1  BMW    1 Series  2011      300.0               6.0            MANUAL
# 2  BMW    1 Series  2011      300.0               6.0            MANUAL
# 3  BMW    1 Series  2011      230.0               6.0            MANUAL
# 4  BMW    1 Series  2011      230.0               6.0            MANUAL
#
#       Driven_Wheels  highway MPG  city mpg   MSRP
# 0  rear wheel drive           26        19  46135
# 1  rear wheel drive           28        19  40650
# 2  rear wheel drive           28        20  36350
# 3  rear wheel drive           28        18  29450
# 4  rear wheel drive           28        18  34500

# %%
df = df.rename(columns={'Engine HP': 'HP', 'Engine Cylinders': 'Cylinders', 'Transmission Type': 'Transmission', 'Driven_Wheels': 'Drive Mode', 'highway MPG': 'MPG-H', 'city mpg': 'MPG-C', 'MSRP': 'Price'})

# %% [markdown]
# #if we dont use df = df.___, we can use inplace = true, it will change in the main dataset. if we dont do any of the 2 it will just show how it will change the data

# %%
df.head()
# Out:
#   Make       Model  Year     HP  Cylinders Transmission        Drive Mode  \
# 0  BMW  1 Series M  2011  335.0        6.0       MANUAL  rear wheel drive
# 1  BMW    1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
# 2  BMW    1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
# 3  BMW    1 Series  2011  230.0        6.0       MANUAL  rear wheel drive
# 4  BMW    1 Series  2011  230.0        6.0       MANUAL  rear wheel drive
#
#    MPG-H  MPG-C  Price
# 0     26     19  46135
# 1     28     19  40650
# 2     28     20  36350
# 3     28     18  29450
# 4     28     18  34500

# %%
df.shape
# Out:
# (11914, 10)

# %%
duplicated_rows = df[df.duplicated()]
print("number of duplicate rows:", duplicated_rows.shape)
# Out:
# number of duplicate rows: (989, 10)

# %%
df.count()
# Out:
# Make            11914
# Model           11914
# Year            11914
# HP              11845
# Cylinders       11884
# Transmission    11914
# Drive Mode      11914
# MPG-H           11914
# MPG-C           11914
# Price           11914
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.count()
# Out:
# Make            10925
# Model           10925
# Year            10925
# HP              10856
# Cylinders       10895
# Transmission    10925
# Drive Mode      10925
# MPG-H           10925
# MPG-C           10925
# Price           10925
# dtype: int64

# %%
df.shape
# Out:
# (10925, 10)

# %%
df
# Out:
#           Make       Model  Year     HP  Cylinders Transmission  \
# 0          BMW  1 Series M  2011  335.0        6.0       MANUAL
# 1          BMW    1 Series  2011  300.0        6.0       MANUAL
# 2          BMW    1 Series  2011  300.0        6.0       MANUAL
# 3          BMW    1 Series  2011  230.0        6.0       MANUAL
# 4          BMW    1 Series  2011  230.0        6.0       MANUAL
# ...        ...         ...   ...    ...        ...          ...
# 11909    Acura         ZDX  2012  300.0        6.0    AUTOMATIC
# 11910    Acura         ZDX  2012  300.0        6.0    AUTOMATIC
# 11911    Acura         ZDX  2012  300.0        6.0    AUTOMATIC
# 11912    Acura         ZDX  2013  300.0        6.0    AUTOMATIC
# 11913  Lincoln      Zephyr  2006  221.0        6.0    AUTOMATIC
#
#               Drive Mode  MPG-H  MPG-C  Price
# 0       rear wheel drive     26     19  46135
# 1       rear wheel drive     28     19  40650
# 2       rear wheel drive     28     20  36350
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10925 entries, 0 to 11913
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Make          10925 non-null  object
#  1   Model         10925 non-null  object
#  2   Year          10925 non-null  int64
#  3   HP            10856 non-null  float64
#  4   Cylinders     10895 non-null  float64
#  5   Transmission  10925 non-null  object
#  6   Drive Mode    10925 non-null  object
#  7   MPG-H         10925 non-null  int64
#  8   MPG-C         10925 non-null  int64
#  9   Price         10925 non-null  int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 938.9+ KB

# %%
df.isnull().sum()
# Out:
# Make             0
# Model            0
# Year             0
# HP              69
# Cylinders       30
# Transmission     0
# Drive Mode       0
# MPG-H            0
# MPG-C            0
# Price            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Make            0
# Model           0
# Year            0
# HP              0
# Cylinders       0
# Transmission    0
# Drive Mode      0
# MPG-H           0
# MPG-C           0
# Price           0
# dtype: int64

# %%
Q1 = df.quantile(0.25, numeric_only=True)
Q3 = df.quantile(0.75, numeric_only=True)  
IQR = Q3 - Q1
print(IQR)
# Out:
# Year             9.0
# HP             130.0
# Cylinders        2.0
# MPG-H            8.0
# MPG-C            6.0
# Price        21327.5
# dtype: float64

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
sns.boxplot(data=df, x='HP')
plt.show()

# %%
sns.boxplot(data=df, x = 'Cylinders')
plt.show()

# %%
sns.boxplot(data=df, x = 'Price')
plt.show()

# %%
sns.boxplot(data=df, x = 'MPG-H')
plt.show()

# %%
sns.boxplot(data=df, x = 'MPG-C')
plt.show()

# %%
df.Make.value_counts().nlargest(30).plot(kind='bar', figsize=(10,5))
plt.title('Top 40 car manufacturers')
plt.xlabel('Car Manufacturer') 
plt.ylabel('Number of Cars')
plt.show()

# %%
df.Make.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title('Top 40 car manufacturers')
plt.xlabel('Car Manufacturer') 
plt.ylabel('Number of Cars')
plt.show()

# %% [markdown]
# # Heat  Maps

# %%
# plt.figure(figsize=(10,5)) this gives the size of the heat map
c = df.corr(numeric_only=  True)
print(c)
sns.heatmap(df.corr(numeric_only=  True), annot=True)
plt.show()
# Out:
#                Year        HP  Cylinders     MPG-H     MPG-C     Price
# Year       1.000000  0.314971  -0.050598  0.284237  0.234135  0.196789
# HP         0.314971  1.000000   0.788007 -0.420281 -0.473551  0.659835
# Cylinders -0.050598  0.788007   1.000000 -0.611576 -0.632407  0.554740
# MPG-H      0.284237 -0.420281  -0.611576  1.000000  0.841229 -0.209150
# MPG-C      0.234135 -0.473551  -0.632407  0.841229  1.000000 -0.234050
# Price      0.196789  0.659835   0.554740 -0.209150 -0.234050  1.000000

# %%
df['Year']
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 11909    2012
# 11910    2012
# 11911    2012
# 11912    2013
# 11913    2006
# Name: Year, Length: 10827, dtype: int64

# %%
df['makemodel'] = df['Make'] + ' ' + df['Model']
df['makemodel']
# Out:
# 0        BMW 1 Series M
# 1          BMW 1 Series
# 2          BMW 1 Series
# 3          BMW 1 Series
# 4          BMW 1 Series
#               ...
# 11909         Acura ZDX
# 11910         Acura ZDX
# 11911         Acura ZDX
# 11912         Acura ZDX
# 11913    Lincoln Zephyr
# Name: makemodel, Length: 10827, dtype: object

# %%
display(df.loc[0:5])
# Out:
#   Make       Model  Year     HP  Cylinders Transmission        Drive Mode  \
# 0  BMW  1 Series M  2011  335.0        6.0       MANUAL  rear wheel drive
# 1  BMW    1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
# 2  BMW    1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
# 3  BMW    1 Series  2011  230.0        6.0       MANUAL  rear wheel drive
# 4  BMW    1 Series  2011  230.0        6.0       MANUAL  rear wheel drive
# 5  BMW    1 Series  2012  230.0        6.0       MANUAL  rear wheel drive
#
#    MPG-H  MPG-C  Price       makemodel
# 0     26     19  46135  BMW 1 Series M
# 1     28     19  40650    BMW 1 Series
# 2     28     20  36350    BMW 1 Series
# 3     28     18  29450    BMW 1 Series
# 4     28     18  34500    BMW 1 Series
# 5     28     18  31200    BMW 1 Series

# %%
display(df.iloc[0:5,0:3])
# Out:
#   Make       Model  Year
# 0  BMW  1 Series M  2011
# 1  BMW    1 Series  2011
# 2  BMW    1 Series  2011
# 3  BMW    1 Series  2011
# 4  BMW    1 Series  2011

# %%
df.set_index('Make', inplace=True)

# %%
df.loc['BMW'].head()
# Out:
#            Model  Year     HP  Cylinders Transmission        Drive Mode  \
# Make
# BMW   1 Series M  2011  335.0        6.0       MANUAL  rear wheel drive
# BMW     1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
# BMW     1 Series  2011  300.0        6.0       MANUAL  rear wheel drive
# BMW     1 Series  2011  230.0        6.0       MANUAL  rear wheel drive
# BMW     1 Series  2011  230.0        6.0       MANUAL  rear wheel drive
#
#       MPG-H  MPG-C  Price       makemodel
# Make
# BMW      26     19  46135  BMW 1 Series M
# BMW      28     19  40650    BMW 1 Series
# BMW      28     20  36350    BMW 1 Series
# BMW      28     18  29450    BMW 1 Series
# BMW      28     18  34500    BMW 1 Series
