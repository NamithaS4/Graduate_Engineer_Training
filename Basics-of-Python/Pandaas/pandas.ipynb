# %% [markdown]
# # Pandas Series

# %%
! pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
s = pd.Series([1, 3, 5, 6, 8], name = 'My Numbers')
print(s)
# Out:
# 0    1
# 1    3
# 2    5
# 3    6
# 4    8
# Name: My Numbers, dtype: int64

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('StressLevelDataset.csv')

# %%
df
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0                14           20                      0          11         2
# 1                15            8                      1          15         5
# 2                12           18                      1          14         2
# 3                16           12                      1          15         4
# 4                16           28                      0           7         2
# ...             ...          ...                    ...         ...       ...
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
# ...

# %%
df.head()
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
df.tail()
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
#       blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 1095               1              3                  2            2
# 1096               3              0                  0            0
# 1097               2              5                  2            2
# 1098               3              1                  4            3
# 1099               3              0                  3            3
#
#       living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
df = pd.read_csv('datasets.csv')

# %%
df.head(6)
# Out:
#             datasetName                                            about  \
# 0    Microbiome Project                American Gut (Microbiome Project)
# 1                 GloBI               Global Biotic Interactions (GloBI)
# 2        Global Climate                   Global Climate Data Since 1929
# 3       CommonCraw 2012              3.5B Web Pages from CommonCraw 2012
# 4     Indiana Webclicks  53.5B Web clicks of 100K users in Indiana Univ.
# 5  Criteo click-through                        Criteo click-through data
#
#                                                 link       categoryName  \
# 0            https://github.com/biocore/American-Gut            Biology
# 1  https://github.com/jhpoelen/eol-globi-data/wik...            Biology
# 2                     http://en.tutiempo.net/climate    Climate/Weather
# 3  http://www.bigdatanews.com/profiles/blogs/big-...  Computer Networks
# 4  http://cnets.indiana.edu/groups/nan/webtraffic...  Computer Networks
# ...

# %%
df.tail(6)
# Out:
#        datasetName                                          about  \
# 55  ClueWeb09 FACC                                 ClueWeb09 FACC
# 56  ClueWeb12 FACC                                 ClueWeb12 FACC
# 57   Google Ngrams                    Google Books Ngrams (2.2TB)
# 58      EDRM Enron    EDRM Enron EMail of 151 users, hosted on S3
# 59         GetGlue                GetGlue - users rating TV shows
# 60  Twitter RepLab  Twitter Data for Online Reputation Management
#
#                                                  link      categoryName  \
# 55           http://lemurproject.org/clueweb09/FACC1/  Natural Language
# 56           http://lemurproject.org/clueweb12/FACC1/  Natural Language
# 57  https://aws.amazon.com/datasets/google-books-n...  Natural Language
# 58  https://aws.amazon.com/datasets/enron-email-data/   Social Networks
# 59  http://getglue-data.s3.amazonaws.com/getglue_s...   Social Networks
# ...

# %%
df.dtypes
# Out:
# datasetName      object
# about            object
# link             object
# categoryName     object
# cloud            object
# vintage         float64
# dtype: object

# %%
df = df.drop('datasetName', axis=1)
df.head(5)
# Out:
#                                              about  \
# 0                American Gut (Microbiome Project)
# 1               Global Biotic Interactions (GloBI)
# 2                   Global Climate Data Since 1929
# 3              3.5B Web Pages from CommonCraw 2012
# 4  53.5B Web clicks of 100K users in Indiana Univ.
#
#                                                 link       categoryName  \
# 0            https://github.com/biocore/American-Gut            Biology
# 1  https://github.com/jhpoelen/eol-globi-data/wik...            Biology
# 2                     http://en.tutiempo.net/climate    Climate/Weather
# 3  http://www.bigdatanews.com/profiles/blogs/big-...  Computer Networks
# 4  http://cnets.indiana.edu/groups/nan/webtraffic...  Computer Networks
#
#     cloud  vintage
# 0  GitHub      NaN
# 1  GitHub      NaN
# 2     NaN   1929.0
# 3     NaN   2012.0
# 4     NaN      NaN

# %%
df = df.rename(columns={'categoryName': 'Category Name'})

# %%
df.head()
# Out:
#                                              about  \
# 0                American Gut (Microbiome Project)
# 1               Global Biotic Interactions (GloBI)
# 2                   Global Climate Data Since 1929
# 3              3.5B Web Pages from CommonCraw 2012
# 4  53.5B Web clicks of 100K users in Indiana Univ.
#
#                                                 link      Category Name  \
# 0            https://github.com/biocore/American-Gut            Biology
# 1  https://github.com/jhpoelen/eol-globi-data/wik...            Biology
# 2                     http://en.tutiempo.net/climate    Climate/Weather
# 3  http://www.bigdatanews.com/profiles/blogs/big-...  Computer Networks
# 4  http://cnets.indiana.edu/groups/nan/webtraffic...  Computer Networks
#
#     cloud  vintage
# 0  GitHub      NaN
# 1  GitHub      NaN
# 2     NaN   1929.0
# 3     NaN   2012.0
# 4     NaN      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   about          61 non-null     object
#  1   link           61 non-null     object
#  2   Category Name  61 non-null     object
#  3   cloud          24 non-null     object
#  4   vintage        31 non-null     float64
# dtypes: float64(1), object(4)
# memory usage: 2.5+ KB

# %%
df.describe()
# Out:
#            vintage
# count    31.000000
# mean   2000.677419
# std      24.436840
# min    1920.000000
# 25%    2006.500000
# 50%    2009.000000
# 75%    2012.000000
# max    2016.000000

# %%
df.shape
# Out:
# (61, 5)

# %% [markdown]
# ## To know about the number of duplicate values present

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 5)

# %% [markdown]
# ## This gives the count of the data in the file

# %%
df.count()
# Out:
# about            61
# link             61
# Category Name    61
# cloud            24
# vintage          31
# dtype: int64

# %% [markdown]
# # There are no duplicates present in this file so there is no change

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (61, 5)

# %%
df.count()
# Out:
# about            2
# link             2
# Category Name    2
# cloud            2
# vintage          2
# dtype: int64

# %% [markdown]
# ## To check how many null values are present

# %%
print(df.isnull().sum())
# Out:
# about             0
# link              0
# Category Name     0
# cloud            37
# vintage          30
# dtype: int64

# %% [markdown]
# ## For removing all null values

# %%
df = df.dropna()

# %%
df.count()
# Out:
# about            2
# link             2
# Category Name    2
# cloud            2
# vintage          2
# dtype: int64

# %%
df.shape
# Out:
# (2, 5)

# %% [markdown]
# ## after doing dropna (it removes all the null values so now it contains only 2 rows)

# %%
print(df.isnull().sum())
# Out:
# about            0
# link             0
# Category Name    0
# cloud            0
# vintage          0
# dtype: int64

# %% [markdown]
# ## Now there are no null values
